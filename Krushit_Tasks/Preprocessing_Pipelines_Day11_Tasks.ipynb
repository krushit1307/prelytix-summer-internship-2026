# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, OneHotEncoder, OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# Task 1: Scaler Selection
# Scenario: Choose the appropriate scaler for each scenario and justify.

print("a) Age (20-70), Income (15K-500K) for SVM classification. -> StandardScaler — continuous numerical, SVM needs scaling.")
print("b) Pixel intensities (0-255) for a neural network. -> MinMaxScaler — brings to [0,1], standard for images.")
print("c) Hospital patient vitals (Heart Rate, Blood Pressure) with occasional extreme outlier values. -> RobustScaler — medical outliers are common.")
print("d) Word frequency counts (0-5000) for KNN text similarity. -> StandardScaler or MinMaxScaler after TF-IDF; or cosine distance (scale-invariant).")

# %%
# Task 2: Encoding Decision
# Scenario: For each feature, choose the right encoding method.

print("a) 'Size': Small / Medium / Large (for clothing orders) -> Ordinal (S<M<L).")
print("b) 'Country': India / USA / Germany / Brazil / (200+ countries in the dataset) -> Target/Frequency encoding (too many for OHE).")
print("c) 'Device_type': Mobile / Desktop / Tablet (for website analytics) -> OHE (3 nominal, no order).")
print("d) 'Customer_tier': Bronze / Silver / Gold / Platinum (loyalty program) -> Ordinal (explicit tier order).")
print("e) 'Marital_status': Single / Married / Divorced -> OHE (no meaningful order).")
