# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC, SVR
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
# Task 1: SVM Concepts Check

print("a) A dataset has 500 training samples. After SVM training, the model has 12 support vectors. How many training samples are needed to make predictions on new data? -> 12 (only support vectors).")
print("b) If you remove 488 non-support-vector points from training and retrain, will the SVM boundary change? -> No — support vectors define the model.")
print("c) Why does a wider margin generally lead to better generalisation? -> Points near boundary are ambiguous; wider margin = smaller chance of misclassifying them.")
print("d) In 2D (2 features), what geometric shape is the SVM decision boundary? -> A straight line.")

# %%
# Task 2: C Parameter Analysis
# Scenario: An SVM model is trained with different C values on a training set.
# C=0.01: Train=72%, Test=71%
# C=1.0: Train=88%, Test=86%
# C=100: Train=98%, Test=79%

print("a) Which C value shows underfitting? What evidence supports this? -> C=0.01 — both accuracies are low (model too simple).")
print("b) Which C value shows overfitting? What evidence supports this? -> C=100 — high train, low test (19% gap).")
print("c) Which C value would you choose for production? Why? -> C=1.0 — best test accuracy with small gap.")
print("d) What does the gap between Train and Test accuracy tell you about C=100? -> Model memorised training noise — wide margin would have generalised better.")
